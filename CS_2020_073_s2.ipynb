# %% [markdown]
# Step 1: Understand and review the dataset.

# %%
import pandas as pd

# %%
# Read the CSV file
df1 = pd.read_csv(r"F:\CS-2020-073\3rd year\semester 2\CSCI 32092 DM & W\Assignment\CS-2020-073\Step 02\Data\sales-data-samples.csv")
df1
# Out:
#                      OrderDate         Category           City        Country  \
# 0     2011-01-04T00:00:00.000Z  Office Supplies        Houston  United States
# 1     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 2     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 3     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 4     2011-01-06T00:00:00.000Z  Office Supplies   Philadelphia  United States
# ...                        ...              ...            ...            ...
# 9989  2014-12-31T00:00:00.000Z  Office Supplies      Fairfield  United States
# 9990  2014-12-31T00:00:00.000Z  Office Supplies      Fairfield  United States
# 9991  2014-12-31T00:00:00.000Z  Office Supplies       Loveland  United States
# 9992  2014-12-31T00:00:00.000Z  Office Supplies  New York City  United States
# 9993  2014-12-31T00:00:00.000Z       Technology  New York City  United States
#
# ...

# %%
# Data Types
print(df1.dtypes)
# Out:
# OrderDate               object
# Category                object
# City                    object
# Country                 object
# CustomerName            object
# Discount               float64
# OrderID                 object
# PostalCode               int64
# ProductName             object
# Profit                   int64
# Quantity                 int64
# Region                  object
# Sales                    int64
# Segment                 object
# ShipDate                object
# ShipMode                object
# State                   object
# Sub_Category            object
# DaystoShipActual         int64
# SalesForecast            int64
# ShipStatus              object
# DaystoShipScheduled      int64
# OrderProfitable        float64
# SalesperCustomer       float64
# ProfitRatio            float64
# SalesaboveTarget       float64
# latitude               float64
# longitude              float64
# dtype: object

# %%
# Finding Missing Values
print(df1.isnull().sum())
# Out:
# OrderDate                 0
# Category                  0
# City                      0
# Country                   0
# CustomerName              0
# Discount                  0
# OrderID                   0
# PostalCode                0
# ProductName               0
# Profit                    0
# Quantity                  0
# Region                    0
# Sales                     0
# Segment                   0
# ShipDate                  0
# ShipMode                  0
# State                     0
# Sub_Category              0
# DaystoShipActual          0
# SalesForecast             0
# ShipStatus                0
# DaystoShipScheduled       0
# OrderProfitable        9994
# SalesperCustomer          0
# ProfitRatio               0
# SalesaboveTarget       9994
# latitude                  0
# longitude                 0
# dtype: int64

# %%
# Finding Duplicates
print(f"Duplicate Rows: {df1.duplicated().sum()}")
# Out:
# Duplicate Rows: 1

# %%
# Identifying First Rows
print(df1.head())
# Out:
#                   OrderDate         Category          City        Country  \
# 0  2011-01-04T00:00:00.000Z  Office Supplies       Houston  United States
# 1  2011-01-05T00:00:00.000Z  Office Supplies    Naperville  United States
# 2  2011-01-05T00:00:00.000Z  Office Supplies    Naperville  United States
# 3  2011-01-05T00:00:00.000Z  Office Supplies    Naperville  United States
# 4  2011-01-06T00:00:00.000Z  Office Supplies  Philadelphia  United States
#
#     CustomerName  Discount         OrderID  PostalCode  \
# 0  Darren Powers       0.2  CA-2011-103800       77095
# 1  Phillina Ober       0.2  CA-2011-112326       60540
# 2  Phillina Ober       0.8  CA-2011-112326       60540
# 3  Phillina Ober       0.2  CA-2011-112326       60540
# 4     Mick Brown       0.2  CA-2011-141817       19143
#
#                                          ProductName  Profit  ...  \
# 0  Message Book, Wirebound, Four 5 1/2 X 4 Forms/...       6  ...
# ...

# %%
# Descriptive Stats
print(df1.describe(include='all'))
# Out:
#                        OrderDate         Category           City  \
# count                       9994             9994           9994
# unique                      1238                3            531
# top     2013-09-06T00:00:00.000Z  Office Supplies  New York City
# freq                          38             6026            915
# mean                         NaN              NaN            NaN
# std                          NaN              NaN            NaN
# min                          NaN              NaN            NaN
# 25%                          NaN              NaN            NaN
# 50%                          NaN              NaN            NaN
# 75%                          NaN              NaN            NaN
# max                          NaN              NaN            NaN
#
#               Country   CustomerName     Discount         OrderID  \
# count            9994           9994  9994.000000            9994
# ...

# %%
# Remove duplicates
df1 = df1.drop_duplicates()
df1
# Out:
#                      OrderDate         Category           City        Country  \
# 0     2011-01-04T00:00:00.000Z  Office Supplies        Houston  United States
# 1     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 2     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 3     2011-01-05T00:00:00.000Z  Office Supplies     Naperville  United States
# 4     2011-01-06T00:00:00.000Z  Office Supplies   Philadelphia  United States
# ...                        ...              ...            ...            ...
# 9989  2014-12-31T00:00:00.000Z  Office Supplies      Fairfield  United States
# 9990  2014-12-31T00:00:00.000Z  Office Supplies      Fairfield  United States
# 9991  2014-12-31T00:00:00.000Z  Office Supplies       Loveland  United States
# 9992  2014-12-31T00:00:00.000Z  Office Supplies  New York City  United States
# 9993  2014-12-31T00:00:00.000Z       Technology  New York City  United States
#
# ...

# %%
#Replace for null columns
df1['OrderProfitable'] = df1['Profit']>0
df1['SalesaboveTarget'] = df1['Sales'] - df1['SalesForecast']
df1.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9696\2331781988.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['OrderProfitable'] = df1['Profit']>0
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9696\2331781988.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['SalesaboveTarget'] = df1['Sales'] - df1['SalesForecast']
#                   OrderDate         Category          City        Country  \
# 0  2011-01-04T00:00:00.000Z  Office Supplies       Houston  United States
# ...

# %%
#check null values
print(df1.isnull().values.any())
# Out:
# False

# %%
df1['OrderDate'] = pd.to_datetime(df1['OrderDate'])
df1['ShipDate'] = pd.to_datetime(df1['ShipDate'])
df1.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9696\1950269232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['OrderDate'] = pd.to_datetime(df1['OrderDate'])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9696\1950269232.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['ShipDate'] = pd.to_datetime(df1['ShipDate'])
#                   OrderDate         Category          City        Country  \
# 0 2011-01-04 00:00:00+00:00  Office Supplies       Houston  United States
# ...

# %%
#  Convert dates
df1['OrderDate'] = pd.to_datetime(df1['OrderDate'])
df1['ShipDate'] = pd.to_datetime(df1['ShipDate'])
print(df1.dtypes)
# Out:
# OrderDate              datetime64[ns, UTC]
# Category                            object
# City                                object
# Country                             object
# CustomerName                        object
# Discount                           float64
# OrderID                             object
# PostalCode                           int64
# ProductName                         object
# Profit                               int64
# Quantity                             int64
# Region                              object
# Sales                                int64
# Segment                             object
# ShipDate               datetime64[ns, UTC]
# ShipMode                            object
# State                               object
# Sub_Category                        object
# DaystoShipActual                     int64
# SalesForecast                        int64
# ShipStatus                          object
# DaystoShipScheduled                  int64
# ...

# %%
# Save cleaned data
df2 = df1.to_csv(r'D:/CS-2020-073/3rd year/semester 2/CSCI 32092 DM & W/Assignment/CS-2020-073/Step 02/Data/cleaned_sales_data.csv', index=False)

# %%
df2 = pd.read_csv(r"D:\CS-2020-073\3rd year\semester 2\CSCI 32092 DM & W\Assignment\CS-2020-073\Step 02\Data\cleaned_sales_data.csv")
df2
# Out:
#                       OrderDate         Category           City  \
# 0     2011-01-04 00:00:00+00:00  Office Supplies        Houston
# 1     2011-01-05 00:00:00+00:00  Office Supplies     Naperville
# 2     2011-01-05 00:00:00+00:00  Office Supplies     Naperville
# 3     2011-01-05 00:00:00+00:00  Office Supplies     Naperville
# 4     2011-01-06 00:00:00+00:00  Office Supplies   Philadelphia
# ...                         ...              ...            ...
# 9988  2014-12-31 00:00:00+00:00  Office Supplies      Fairfield
# 9989  2014-12-31 00:00:00+00:00  Office Supplies      Fairfield
# 9990  2014-12-31 00:00:00+00:00  Office Supplies       Loveland
# 9991  2014-12-31 00:00:00+00:00  Office Supplies  New York City
# 9992  2014-12-31 00:00:00+00:00       Technology  New York City
#
#             Country      CustomerName  Discount         OrderID  PostalCode  \
# 0     United States     Darren Powers       0.2  CA-2011-103800       77095
# ...
